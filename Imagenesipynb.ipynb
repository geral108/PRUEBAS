# %% [markdown]
# <a href="https://colab.research.google.com/github/geral108/PRUEBAS/blob/main/Imagenesipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trabajando con imagenes

# %%
from os import path
import cv2 #esta librearia ayuda a poner filtros; marcos a las imagenes
import matplotlib.pyplot as plt #genera un plano cartesiano paa poder poner ahi las imagenes
path = "/content/perrito.png"
img = cv2.imread(path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
